# %%
import pandas as pd
import sqlite3
from tqdm.notebook import tqdm

# %%
chunk_docgraph = pd.read_csv('../data/DocGraph_Hop_Teaming_2018_Commercial/DocGraph_Hop_Teaming_2018.csv', 
                              nrows = 100)   

# CAN ALSO DO chunksize, BUT IT WILL GIVE YOU A TextFileReader OBJECT, 
#  WHICH YOU CANNOT RUN DATAFRAME FUNCTIONS ON

# %%
chunk_docgraph

# str(chunk_docgraph)
# next(chunk_docgraph)
# Out:
#       from_npi      to_npi  patient_count  transaction_count  \
# 0   1508062167  1730166109            350                370
# 1   1508065640  1730166109             25                 25
# 2   1508052093  1730166109             16                 16
# 3   1508172545  1730166109             14                 14
# 4   1508285131  1730166109             20                 21
# ..         ...         ...            ...                ...
# 95  1508178229  1730166893             31                 32
# 96  1508196445  1730166893             23                 24
# 97  1508811076  1730166935             14                 15
# 98  1508871252  1730166935             29                 31
# 99  1508845850  1730166943             23                 61
#
#     average_day_wait  std_day_wait
# 0             53.922        72.612
# 1             49.800        55.006
# 2            109.500        70.593
# 3            103.357        75.483
# 4             89.952        89.880
# ...

# %%
print(type(chunk_docgraph))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# THIS DOES NOT WORK WITH chunksize, ONLY WITH nrows()

chunk_docgraph.info()
# chunk_docgraph.columns
# chunk_docgraph.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   from_npi           100 non-null    int64
#  1   to_npi             100 non-null    int64
#  2   patient_count      100 non-null    int64
#  3   transaction_count  100 non-null    int64
#  4   average_day_wait   100 non-null    float64
#  5   std_day_wait       100 non-null    float64
# dtypes: float64(2), int64(4)
# memory usage: 4.8 KB

# %%
# TO DO

# db = sqlite3.connect('data/DocGraph_Hop_Teaming_2018.sqlite')

#for chunk in tqdm(pd.read_csv('data/DocGraph_Hop_Teaming_2018_Commercial/DocGraph_Hop_Teaming_2018.csv', 
#                              chunksize = 10000)):
#    chunk.columns = [x.lower().replace(' ', '_') for x in chunk.columns]   
#    chunk.to_sql('calls', db, if_exists = 'append', index = False)

# %%
chunk_npi = pd.read_csv('../data/NPPES_Data_Dissemination_February_2022/npidata_pfile_20050523-20220213.csv', 
                        nrows = 100)

# %%
pd.set_option('display.max_columns', 330)

# %%
chunk_npi
# Out:
#            NPI  Entity Type Code  Replacement NPI  \
# 0   1679576722               1.0              NaN
# 1   1588667638               1.0              NaN
# 2   1497758544               2.0              NaN
# 3   1306849450               NaN              NaN
# 4   1215930367               1.0              NaN
# ..         ...               ...              ...
# 95  1649273673               1.0              NaN
# 96  1083617013               2.0              NaN
# 97  1992708929               2.0              NaN
# 98  1801899836               1.0              NaN
# 99  1710980743               1.0              NaN
#
#    Employer Identification Number (EIN)  \
# 0                                   NaN
# 1                                   NaN
# 2                             <UNAVAIL>
# 3                                   NaN
# 4                                   NaN
# ..                                  ...
# 95                                  NaN
# ...

# %%
chunk_npi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Columns: 330 entries, NPI to Certification Date
# dtypes: float64(219), int64(1), object(110)
# memory usage: 257.9+ KB

# %%
# ONLY Switches 1 - 4 HAVE VALUES FOR THESE FIRST 100 ROWS--
#   I PLAN TO CREATE A SQLite TEST DATABASE WITH JUST THE FIRST 4
chunk_npi[(chunk_npi['Healthcare Provider Primary Taxonomy Switch_15'] == 'Y')]
# Out:
# Empty DataFrame
# ...

# %%
chunk_nucc_taxonomy = pd.read_csv('../data/nucc_taxonomy_220.csv', 
                                  nrows = 100)

# %%
chunk_nucc_taxonomy
# Out:
#           Code                             Grouping        Classification  \
# 0   193200000X                                Group       Multi-Specialty
# 1   193400000X                                Group      Single Specialty
# 2   207K00000X  Allopathic & Osteopathic Physicians  Allergy & Immunology
# 3   207KA0200X  Allopathic & Osteopathic Physicians  Allergy & Immunology
# 4   207KI0005X  Allopathic & Osteopathic Physicians  Allergy & Immunology
# ..         ...                                  ...                   ...
# 95  207WX0120X  Allopathic & Osteopathic Physicians         Ophthalmology
# 96  207WX0009X  Allopathic & Osteopathic Physicians         Ophthalmology
# 97  207WX0109X  Allopathic & Osteopathic Physicians         Ophthalmology
# 98  207WX0200X  Allopathic & Osteopathic Physicians         Ophthalmology
# 99  207WX0110X  Allopathic & Osteopathic Physicians         Ophthalmology
#
#                                        Specialization  \
# ...

# %%
chunk_zip_cbsa = pd.read_excel('../data/ZIP_CBSA_122021.xlsx',
                               nrows = 100)

# %%
print(type(chunk_zip_cbsa))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
chunk_zip_cbsa
# Out:
#       zip   cbsa usps_zip_pref_city usps_zip_pref_state  res_ratio  bus_ratio  \
# 0     683  41900         SAN GERMAN                  PR   0.999842    1.00000
# 1     683  32420         SAN GERMAN                  PR   0.000158    0.00000
# 2     923  41980           SAN JUAN                  PR   1.000000    1.00000
# 3    1010  44140          BRIMFIELD                  MA   0.976896    1.00000
# 4    1010  49340          BRIMFIELD                  MA   0.023104    0.00000
# ..    ...    ...                ...                 ...        ...        ...
# 95  12474  99999            ROXBURY                  NY   1.000000    1.00000
# 96  12786  99999         WHITE LAKE                  NY   1.000000    1.00000
# 97  12845  24020        LAKE GEORGE                  NY   1.000000    1.00000
# 98  12832  24020          GRANVILLE                  NY   1.000000    1.00000
# 99  12944  99999         KEESEVILLE                  NY   0.580929    0.65625
#
#     oth_ratio  tot_ratio
# ...

# %%
chunk_zip_cbsa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   zip                  100 non-null    int64
#  1   cbsa                 100 non-null    int64
#  2   usps_zip_pref_city   100 non-null    object
#  3   usps_zip_pref_state  100 non-null    object
#  4   res_ratio            100 non-null    float64
#  5   bus_ratio            100 non-null    float64
#  6   oth_ratio            100 non-null    float64
#  7   tot_ratio            100 non-null    float64
# dtypes: float64(4), int64(2), object(2)
# memory usage: 6.4+ KB
