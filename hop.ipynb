# %%
import pandas as pd

# %%
DocGraph = pd.read_csv('./data/DocGraph/DocGraph_Hop_Teaming_2018.csv', nrows = 100)

# %%
DocGraph.head()
# Out:
#      from_npi      to_npi  patient_count  transaction_count  average_day_wait  \
# 0  1508062167  1730166109            350                370            53.922
# 1  1508065640  1730166109             25                 25            49.800
# 2  1508052093  1730166109             16                 16           109.500
# 3  1508172545  1730166109             14                 14           103.357
# 4  1508285131  1730166109             20                 21            89.952
#
#    std_day_wait
# 0        72.612
# 1        55.006
# 2        70.593
# 3        75.483
# 4        89.880

# %%
endpoint = pd.read_csv('./data/NPPES/endpoint_pfile_20050523-20220213.csv', nrows = 100)

# %%
endpoint.head()
# Out:
#           NPI Endpoint Type Endpoint Type Description  \
# 0  1154324382        DIRECT  Direct Messaging Address
# 1  1154324382        DIRECT  Direct Messaging Address
# 2  1962405175        DIRECT  Direct Messaging Address
# 3  1699778894        DIRECT  Direct Messaging Address
# 4  1396748596        DIRECT  Direct Messaging Address
#
#                                            Endpoint Affiliation  \
# 0         Richard.Close@SEP.EClinicalDirectPlus.com           N
# 1                         rclose13800@MHSDIRECT.NET           N
# 2         fredericstelzer@epgi.allscriptsdirect.net           N
# 3                      aawomolo@direct.iuhealth.org           N
# 4  CHRISTIANO.CALDEIRA@hca4.eclinicaldirectplus.com           N
#
#   Endpoint Description Affiliation Legal Business Name Use Code  \
# 0                  NaN                             NaN   DIRECT
# 1                  NaN                             NaN      NaN
# ...

# %%
provider = pd.read_csv('./data/NPPES/npidata_pfile_20050523-20220213.csv', nrows = 100)

# %%
provider.head()
# Out:
#           NPI  Entity Type Code  Replacement NPI  \
# 0  1679576722               1.0              NaN
# 1  1588667638               1.0              NaN
# 2  1497758544               2.0              NaN
# 3  1306849450               NaN              NaN
# 4  1215930367               1.0              NaN
#
#   Employer Identification Number (EIN)  \
# 0                                  NaN
# 1                                  NaN
# 2                            <UNAVAIL>
# 3                                  NaN
# 4                                  NaN
#
#   Provider Organization Name (Legal Business Name)  \
# 0                                              NaN
# 1                                              NaN
# 2           CUMBERLAND COUNTY HOSPITAL SYSTEM, INC
# 3                                              NaN
# 4                                              NaN
#
#   Provider Last Name (Legal Name) Provider First Name Provider Middle Name  \
# ...

# %%
NPI_provider = pd.read_csv('./data/NPPES/othername_pfile_20050523-20220213.csv', nrows = 100)

# %%
NPI_provider.head()
# Out:
#           NPI          Provider Other Organization Name  \
# 0  1023011053   Vine Discount Pharmacy & Medical Supply
# 1  1023011178  Napa Valley Hospice & Adult Day Services
# 2  1043213093                   HOME IV SPECIALISTS INC
# 3  1053314252                         Alliance HomeCare
# 4  1134122328                 Horizon Coral Springs LLC
#
#    Provider Other Organization Name Type Code
# 0                                           3
# 1                                           4
# 2                                           3
# 3                                           3
# 4                                           3

# %%
merged_provider = pd.merge(endpoint, provider, on = 'NPI', how = 'left')

# %%
merged_provider.columns
# Out:
# Index(['NPI', 'Endpoint Type', 'Endpoint Type Description', 'Endpoint',
#        'Affiliation', 'Endpoint Description',
#        'Affiliation Legal Business Name', 'Use Code', 'Use Description',
#        'Other Use Description',
#        ...
#        'Healthcare Provider Taxonomy Group_7',
#        'Healthcare Provider Taxonomy Group_8',
#        'Healthcare Provider Taxonomy Group_9',
#        'Healthcare Provider Taxonomy Group_10',
#        'Healthcare Provider Taxonomy Group_11',
#        'Healthcare Provider Taxonomy Group_12',
#        'Healthcare Provider Taxonomy Group_13',
#        'Healthcare Provider Taxonomy Group_14',
#        'Healthcare Provider Taxonomy Group_15', 'Certification Date'],
#       dtype='object', length=348)

# %%
taxonomy.head()
# Out:
#          Code                             Grouping        Classification  \
# 0  193200000X                                Group       Multi-Specialty
# 1  193400000X                                Group      Single Specialty
# 2  207K00000X  Allopathic & Osteopathic Physicians  Allergy & Immunology
# 3  207KA0200X  Allopathic & Osteopathic Physicians  Allergy & Immunology
# 4  207KI0005X  Allopathic & Osteopathic Physicians  Allergy & Immunology
#
#                      Specialization  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                           Allergy
# 4  Clinical & Laboratory Immunology
#
#                                           Definition  \
# 0  A business group of one or more individual pra...
# 1  A business group of one or more individual pra...
# 2  An allergist-immunologist is trained in evalua...
# 3                              Definition to come...
# ...
